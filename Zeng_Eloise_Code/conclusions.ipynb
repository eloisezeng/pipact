# %%
import pandas as pd
index = ['Humidity, Temperature, RSSI', 'Humidity, RSSI', 'Temperature, RSSI', 'RSSI']
data = {'Training Accuracy': [0.65, 0.63, 0.63, 0.63],
        'Test accuracy': [0.59, 0.59, 0.59, 0.57],
        'F1 Score (Training)': [0.548, 0.535, 0.524, 0.512],
        'F1 Score (Test)': [0.516, 0.516, 0.516,  0.5],
        'Micro-average ROC Curve Area (Training)':[0.71, 0.71, 0.71, 0.71],
        'Micro-average ROC Curve Area (Test)':[0.64, 0.64, 0.65, 0.66],
        'Macro-average ROC Curve Area (Training)':[0.71, 0.71, 0.71, 0.70],
        'Macro-average ROC Curve Area (Test)':[0.64, 0.64, 0.66, 0.67],
       }
conclusions = pd.DataFrame(data=data, index=index)
conclusions.transpose()
# Out:
#                                          Humidity, Temperature, RSSI  \
# Training Accuracy                                              0.650
# Test accuracy                                                  0.590
# F1 Score (Training)                                            0.548
# F1 Score (Test)                                                0.516
# Micro-average ROC Curve Area (Training)                        0.710
# Micro-average ROC Curve Area (Test)                            0.640
# Macro-average ROC Curve Area (Training)                        0.710
# Macro-average ROC Curve Area (Test)                            0.640
#
#                                          Humidity, RSSI  Temperature, RSSI  \
# Training Accuracy                                 0.630              0.630
# Test accuracy                                     0.590              0.590
# F1 Score (Training)                               0.535              0.524
# ...
